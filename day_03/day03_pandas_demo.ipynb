# %%
import numpy as np
stock_change = np.random.normal(0, 1, (10, 5))

# %%
stock_change
# Out:
# array([[-4.63888155e-01, -1.52213658e+00,  1.41368227e+00,
#          8.12590564e-01, -4.74606672e-01],
#        [-7.37975591e-01,  1.70897386e-01,  1.92713119e-01,
#         -1.25595864e+00, -2.87801023e-01],
#        [-2.67282278e-01, -5.05565222e-01, -5.83022929e-01,
#         -7.25733676e-01, -1.09553327e+00],
#        [ 4.75923111e-01,  2.73330472e-03,  6.84082139e-01,
#          3.71306227e-02, -7.68018433e-02],
#        [-3.61019213e-01,  2.79677622e+00,  1.36358996e+00,
#         -2.25941901e-01, -1.13107979e+00],
#        [-5.15933494e-01, -3.26740648e-01,  1.23655000e+00,
#          1.19295783e+00, -1.68294709e+00],
#        [ 1.39539399e+00,  1.53671056e+00, -1.05656475e+00,
#         -7.44120299e-01,  1.20693948e-01],
#        [-1.10368980e+00,  4.63741193e-01, -1.34050230e+00,
#         -1.42332366e+00,  3.41758151e-01],
#        [ 5.15409885e-01, -4.40663814e-01, -1.05992770e+00,
#         -1.12644834e+00, -1.20941767e+00],
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(stock_change)
# Out:
#           0         1         2         3         4
# 0 -0.463888 -1.522137  1.413682  0.812591 -0.474607
# 1 -0.737976  0.170897  0.192713 -1.255959 -0.287801
# 2 -0.267282 -0.505565 -0.583023 -0.725734 -1.095533
# 3  0.475923  0.002733  0.684082  0.037131 -0.076802
# 4 -0.361019  2.796776  1.363590 -0.225942 -1.131080
# 5 -0.515933 -0.326741  1.236550  1.192958 -1.682947
# 6  1.395394  1.536711 -1.056565 -0.744120  0.120694
# 7 -1.103690  0.463741 -1.340502 -1.423324  0.341758
# 8  0.515410 -0.440664 -1.059928 -1.126448 -1.209418
# 9  0.122598  0.144161  2.489585  1.076430 -0.920108

# %%
# 添加行索引
stock = ["股票{}".format(i) for i in range(10)]

# %%
pd.DataFrame(stock_change, index=stock)
# Out:
#             0         1         2         3         4
# 股票0 -0.463888 -1.522137  1.413682  0.812591 -0.474607
# 股票1 -0.737976  0.170897  0.192713 -1.255959 -0.287801
# 股票2 -0.267282 -0.505565 -0.583023 -0.725734 -1.095533
# 股票3  0.475923  0.002733  0.684082  0.037131 -0.076802
# 股票4 -0.361019  2.796776  1.363590 -0.225942 -1.131080
# 股票5 -0.515933 -0.326741  1.236550  1.192958 -1.682947
# 股票6  1.395394  1.536711 -1.056565 -0.744120  0.120694
# 股票7 -1.103690  0.463741 -1.340502 -1.423324  0.341758
# 股票8  0.515410 -0.440664 -1.059928 -1.126448 -1.209418
# 股票9  0.122598  0.144161  2.489585  1.076430 -0.920108

# %%
# 添加列索引
date = pd.date_range("2025.08.07", periods=5, freq="B")

# %%
date
# Out:
# DatetimeIndex(['2025-08-07', '2025-08-08', '2025-08-11', '2025-08-12',
#                '2025-08-13'],
#               dtype='datetime64[ns]', freq='B')

# %%
data = pd.DataFrame(stock_change, index=stock, columns=date)

# %%
data
# Out:
#      2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票0   -0.463888   -1.522137    1.413682    0.812591   -0.474607
# 股票1   -0.737976    0.170897    0.192713   -1.255959   -0.287801
# 股票2   -0.267282   -0.505565   -0.583023   -0.725734   -1.095533
# 股票3    0.475923    0.002733    0.684082    0.037131   -0.076802
# 股票4   -0.361019    2.796776    1.363590   -0.225942   -1.131080
# 股票5   -0.515933   -0.326741    1.236550    1.192958   -1.682947
# 股票6    1.395394    1.536711   -1.056565   -0.744120    0.120694
# 股票7   -1.103690    0.463741   -1.340502   -1.423324    0.341758
# 股票8    0.515410   -0.440664   -1.059928   -1.126448   -1.209418
# 股票9    0.122598    0.144161    2.489585    1.076430   -0.920108

# %% [markdown]
# ###  DataFrame的属性

# %%
data # shape (10, 5)
# Out:
#      2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票0   -0.463888   -1.522137    1.413682    0.812591   -0.474607
# 股票1   -0.737976    0.170897    0.192713   -1.255959   -0.287801
# 股票2   -0.267282   -0.505565   -0.583023   -0.725734   -1.095533
# 股票3    0.475923    0.002733    0.684082    0.037131   -0.076802
# 股票4   -0.361019    2.796776    1.363590   -0.225942   -1.131080
# 股票5   -0.515933   -0.326741    1.236550    1.192958   -1.682947
# 股票6    1.395394    1.536711   -1.056565   -0.744120    0.120694
# 股票7   -1.103690    0.463741   -1.340502   -1.423324    0.341758
# 股票8    0.515410   -0.440664   -1.059928   -1.126448   -1.209418
# 股票9    0.122598    0.144161    2.489585    1.076430   -0.920108

# %%
data.shape
# Out:
# (10, 5)

# %%
data.index
# Out:
# Index(['股票0', '股票1', '股票2', '股票3', '股票4', '股票5', '股票6', '股票7', '股票8', '股票9'], dtype='object')

# %%
data.columns
# Out:
# DatetimeIndex(['2025-08-07', '2025-08-08', '2025-08-11', '2025-08-12',
#                '2025-08-13'],
#               dtype='datetime64[ns]', freq='B')

# %%
data.values
# Out:
# array([[-4.63888155e-01, -1.52213658e+00,  1.41368227e+00,
#          8.12590564e-01, -4.74606672e-01],
#        [-7.37975591e-01,  1.70897386e-01,  1.92713119e-01,
#         -1.25595864e+00, -2.87801023e-01],
#        [-2.67282278e-01, -5.05565222e-01, -5.83022929e-01,
#         -7.25733676e-01, -1.09553327e+00],
#        [ 4.75923111e-01,  2.73330472e-03,  6.84082139e-01,
#          3.71306227e-02, -7.68018433e-02],
#        [-3.61019213e-01,  2.79677622e+00,  1.36358996e+00,
#         -2.25941901e-01, -1.13107979e+00],
#        [-5.15933494e-01, -3.26740648e-01,  1.23655000e+00,
#          1.19295783e+00, -1.68294709e+00],
#        [ 1.39539399e+00,  1.53671056e+00, -1.05656475e+00,
#         -7.44120299e-01,  1.20693948e-01],
#        [-1.10368980e+00,  4.63741193e-01, -1.34050230e+00,
#         -1.42332366e+00,  3.41758151e-01],
#        [ 5.15409885e-01, -4.40663814e-01, -1.05992770e+00,
#         -1.12644834e+00, -1.20941767e+00],
# ...

# %%
data.T
# Out:
#                  股票0       股票1       股票2       股票3       股票4       股票5  \
# 2025-08-07 -0.463888 -0.737976 -0.267282  0.475923 -0.361019 -0.515933
# 2025-08-08 -1.522137  0.170897 -0.505565  0.002733  2.796776 -0.326741
# 2025-08-11  1.413682  0.192713 -0.583023  0.684082  1.363590  1.236550
# 2025-08-12  0.812591 -1.255959 -0.725734  0.037131 -0.225942  1.192958
# 2025-08-13 -0.474607 -0.287801 -1.095533 -0.076802 -1.131080 -1.682947
#
#                  股票6       股票7       股票8       股票9
# 2025-08-07  1.395394 -1.103690  0.515410  0.122598
# 2025-08-08  1.536711  0.463741 -0.440664  0.144161
# 2025-08-11 -1.056565 -1.340502 -1.059928  2.489585
# 2025-08-12 -0.744120 -1.423324 -1.126448  1.076430
# 2025-08-13  0.120694  0.341758 -1.209418 -0.920108

# %%
data.head(3)
# Out:
#      2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票0   -0.463888   -1.522137    1.413682    0.812591   -0.474607
# 股票1   -0.737976    0.170897    0.192713   -1.255959   -0.287801
# 股票2   -0.267282   -0.505565   -0.583023   -0.725734   -1.095533

# %%
data.head()
# Out:
#      2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票0   -0.463888   -1.522137    1.413682    0.812591   -0.474607
# 股票1   -0.737976    0.170897    0.192713   -1.255959   -0.287801
# 股票2   -0.267282   -0.505565   -0.583023   -0.725734   -1.095533
# 股票3    0.475923    0.002733    0.684082    0.037131   -0.076802
# 股票4   -0.361019    2.796776    1.363590   -0.225942   -1.131080

# %%
data.tail(2)
# Out:
#      2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票8    0.515410   -0.440664   -1.059928   -1.126448   -1.209418
# 股票9    0.122598    0.144161    2.489585    1.076430   -0.920108

# %%
data.tail()
# Out:
#      2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票5   -0.515933   -0.326741    1.236550    1.192958   -1.682947
# 股票6    1.395394    1.536711   -1.056565   -0.744120    0.120694
# 股票7   -1.103690    0.463741   -1.340502   -1.423324    0.341758
# 股票8    0.515410   -0.440664   -1.059928   -1.126448   -1.209418
# 股票9    0.122598    0.144161    2.489585    1.076430   -0.920108

# %% [markdown]
# ### 修改行列索引值

# %%
data.head()
# Out:
#      2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票0   -0.463888   -1.522137    1.413682    0.812591   -0.474607
# 股票1   -0.737976    0.170897    0.192713   -1.255959   -0.287801
# 股票2   -0.267282   -0.505565   -0.583023   -0.725734   -1.095533
# 股票3    0.475923    0.002733    0.684082    0.037131   -0.076802
# 股票4   -0.361019    2.796776    1.363590   -0.225942   -1.131080

# %%
# data.index[2] = "股票88" # 不能单独修改索引，必须整体修改，行列都不行

# %%
stock_ = ["股票_{}".format(i) for i in range(10)]

# %%
data.index = stock_

# %%
data.index
# Out:
# Index(['股票_0', '股票_1', '股票_2', '股票_3', '股票_4', '股票_5', '股票_6', '股票_7', '股票_8',
#        '股票_9'],
#       dtype='object')

# %%
data
# Out:
#       2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票_0   -0.463888   -1.522137    1.413682    0.812591   -0.474607
# 股票_1   -0.737976    0.170897    0.192713   -1.255959   -0.287801
# 股票_2   -0.267282   -0.505565   -0.583023   -0.725734   -1.095533
# 股票_3    0.475923    0.002733    0.684082    0.037131   -0.076802
# 股票_4   -0.361019    2.796776    1.363590   -0.225942   -1.131080
# 股票_5   -0.515933   -0.326741    1.236550    1.192958   -1.682947
# 股票_6    1.395394    1.536711   -1.056565   -0.744120    0.120694
# 股票_7   -1.103690    0.463741   -1.340502   -1.423324    0.341758
# 股票_8    0.515410   -0.440664   -1.059928   -1.126448   -1.209418
# 股票_9    0.122598    0.144161    2.489585    1.076430   -0.920108

# %% [markdown]
# ### 重设索引

# %%
data.reset_index(drop=False)
# Out:
#   index  2025-08-07 00:00:00  2025-08-08 00:00:00  2025-08-11 00:00:00  \
# 0  股票_0            -0.463888            -1.522137             1.413682
# 1  股票_1            -0.737976             0.170897             0.192713
# 2  股票_2            -0.267282            -0.505565            -0.583023
# 3  股票_3             0.475923             0.002733             0.684082
# 4  股票_4            -0.361019             2.796776             1.363590
# 5  股票_5            -0.515933            -0.326741             1.236550
# 6  股票_6             1.395394             1.536711            -1.056565
# 7  股票_7            -1.103690             0.463741            -1.340502
# 8  股票_8             0.515410            -0.440664            -1.059928
# 9  股票_9             0.122598             0.144161             2.489585
#
#    2025-08-12 00:00:00  2025-08-13 00:00:00
# 0             0.812591            -0.474607
# 1            -1.255959            -0.287801
# 2            -0.725734            -1.095533
# ...

# %% [markdown]
# ### 设置新索引

# %%
df = pd.DataFrame({'month': [1, 4, 7, 10],
                    'year': [2012, 2014, 2013, 2014],
                    'sale':[55, 40, 84, 31]})

# %%
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
# 以月份设置新的索引
df.set_index("month", drop=True)
# Out:
#        year  sale
# month
# 1      2012    55
# 4      2014    40
# 7      2013    84
# 10     2014    31

# %%
# 设置多个索引，以年和月份
new_df = df.set_index(["year", "month"])

# %%
new_df
# Out:
#             sale
# year month
# 2012 1        55
# 2014 4        40
# 2013 7        84
# 2014 10       31

# %%
new_df.index
# Out:
# MultiIndex([(2012,  1),
#             (2014,  4),
#             (2013,  7),
#             (2014, 10)],
#            names=['year', 'month'])

# %%
new_df.index.names
# Out:
# FrozenList(['year', 'month'])

# %%
new_df.index.levels
# Out:
# FrozenList([[2012, 2013, 2014], [1, 4, 7, 10]])

# %% [markdown]
# ### Panel

# %%
p = pd.Panel(np.arange(24).reshape(4,3,2),
                 items=list('ABCD'),
                 major_axis=pd.date_range('20130101', periods=3),
                 minor_axis=['first', 'second'])

# %%
p

# %%
p["A"]

# %%
p["D"]

# %%
p.major_xs("2025-08-07")

# %%
p.minor_xs("first")

# %%
data
# Out:
#       2025-08-07  2025-08-08  2025-08-11  2025-08-12  2025-08-13
# 股票_0   -0.463888   -1.522137    1.413682    0.812591   -0.474607
# 股票_1   -0.737976    0.170897    0.192713   -1.255959   -0.287801
# 股票_2   -0.267282   -0.505565   -0.583023   -0.725734   -1.095533
# 股票_3    0.475923    0.002733    0.684082    0.037131   -0.076802
# 股票_4   -0.361019    2.796776    1.363590   -0.225942   -1.131080
# 股票_5   -0.515933   -0.326741    1.236550    1.192958   -1.682947
# 股票_6    1.395394    1.536711   -1.056565   -0.744120    0.120694
# 股票_7   -1.103690    0.463741   -1.340502   -1.423324    0.341758
# 股票_8    0.515410   -0.440664   -1.059928   -1.126448   -1.209418
# 股票_9    0.122598    0.144161    2.489585    1.076430   -0.920108

# %%
data.iloc[1, :]
# Out:
# 2025-08-07   -0.737976
# 2025-08-08    0.170897
# 2025-08-11    0.192713
# 2025-08-12   -1.255959
# 2025-08-13   -0.287801
# Freq: B, Name: 股票_1, dtype: float64

# %% [markdown]
# ### Series

# %%
sr = data.iloc[1, :]

# %%
sr
# Out:
# 2025-08-07   -0.737976
# 2025-08-08    0.170897
# 2025-08-11    0.192713
# 2025-08-12   -1.255959
# 2025-08-13   -0.287801
# Freq: B, Name: 股票_1, dtype: float64

# %%
sr.values
# Out:
# array([-0.73797559,  0.17089739,  0.19271312, -1.25595864, -0.28780102])

# %%
type(sr.values)
# Out:
# numpy.ndarray

# %%
pd.Series(np.arange(3, 9, 2), index=["a", "b", "c"])
# Out:
# a    3
# b    5
# c    7
# dtype: int32

# %%
pd.Series({'red':100, 'blue':200, 'green': 500, 'yellow':1000})
# Out:
# red        100
# blue       200
# green      500
# yellow    1000
# dtype: int64

# %%
data1 = data.T

# %%
data1
# Out:
#                 股票_0      股票_1      股票_2      股票_3      股票_4      股票_5  \
# 2025-08-07 -0.463888 -0.737976 -0.267282  0.475923 -0.361019 -0.515933
# 2025-08-08 -1.522137  0.170897 -0.505565  0.002733  2.796776 -0.326741
# 2025-08-11  1.413682  0.192713 -0.583023  0.684082  1.363590  1.236550
# 2025-08-12  0.812591 -1.255959 -0.725734  0.037131 -0.225942  1.192958
# 2025-08-13 -0.474607 -0.287801 -1.095533 -0.076802 -1.131080 -1.682947
#
#                 股票_6      股票_7      股票_8      股票_9
# 2025-08-07  1.395394 -1.103690  0.515410  0.122598
# 2025-08-08  1.536711  0.463741 -0.440664  0.144161
# 2025-08-11 -1.056565 -1.340502 -1.059928  2.489585
# 2025-08-12 -0.744120 -1.423324 -1.126448  1.076430
# 2025-08-13  0.120694  0.341758 -1.209418 -0.920108

# %%
type(data1["股票_0"])
# Out:
# pandas.core.series.Series

# %%
data1["股票_0"]
# Out:
# 2025-08-07   -0.463888
# 2025-08-08   -1.522137
# 2025-08-11    1.413682
# 2025-08-12    0.812591
# 2025-08-13   -0.474607
# Freq: B, Name: 股票_0, dtype: float64

# %%
data1["股票_0"]["2025-08-07"]
# Out:
# -0.4638881554148151

# %% [markdown]
# ### 4.2 基本数据操作

# %%
data = pd.read_csv("./stock_day.csv")

# %%
data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-22  21.446  21.909  23.137  35397.58  39904.78  60149.60      0.90
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58

# %%
data = data.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"], axis=1)

# %%
data.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
stock_change[1, 1] # numpy可以数字索引
# Out:
# 0.17089738607015803

# %%
# data[1, 0] # 不能直接进行数字索引

# %%
data["open"]["2018-02-26"] # 直接行列索引，先列后行
# Out:
# 22.8

# %%
data.loc["2018-02-26"]["open"] # 先行后列索引
# Out:
# 22.8

# %%
data.loc["2018-02-26"]["open"] # 先列后行索引
# Out:
# 22.8

# %%
data.loc["2018-02-26", "open"] # 先列后行索引
# Out:
# 22.8

# %%
data.iloc[1, 0]
# Out:
# 22.8

# %%
# 获取行第1天到第4天，['open', 'close', 'high', 'low']这个四个指标的结果，组合索引，数字、名字混用
# data.ix[:4, ['open', 'close', 'high', 'low']] # 自 pandas 0.20.0 起就被弃用，后续版本已经没有了

# %%
data.loc['2018-02-26', ['open','close','high','low']]
# Out:
# open     22.80
# close    23.53
# high     23.78
# low      22.80
# Name: 2018-02-26, dtype: float64

# %%
data.loc["2018-02-26", ["open", "close"]]
# Out:
# open     22.80
# close    23.53
# Name: 2018-02-26, dtype: float64

# %%
data.loc[["2018-02-22", "2018-02-23"], ["open", "close"]]
# Out:
#              open  close
# 2018-02-22  22.25  22.28
# 2018-02-23  22.88  22.82

# %% [markdown]
# ### 赋值操作

# %%
data.open = 100

# %%
data
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26   100  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48   23331.04          0.44      2.05
# ...          ...    ...    ...    ...        ...           ...       ...
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# ...

# %%
data.iloc[1, 0] = 222

# %%
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %% [markdown]
# ### 排序

# %%
data.sort_values(by=["high", "p_change"], ascending=False).head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-06-10   100  36.35  33.85  32.23  269033.12          0.51      1.53
# 2015-06-12   100  35.98  35.21  34.01  159825.88          0.82      2.38
# 2017-10-31   100  35.22  34.44  32.20  361660.88          2.38      7.42
# 2015-06-15   100  34.99  31.69  31.69  199369.53         -3.52    -10.00
# 2015-06-11   100  34.98  34.39  32.51  173075.73          0.54      1.59
#
#             turnover
# 2015-06-10      9.21
# 2015-06-12      5.47
# 2017-10-31      9.05
# 2015-06-15      6.82
# 2015-06-11      5.92

# %%
data.sort_values(by=["high", "p_change"], ascending=True).head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-09-07   100  13.38  12.77  12.63   52490.04          0.37      2.98
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
#
#             turnover
# 2015-03-02      3.30
# 2015-03-04      2.30
# 2015-03-03      4.76
# 2015-09-07      1.80
# 2015-03-05      3.19

# %%
data.sort_index().head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
#
#             turnover
# 2015-03-02      3.30
# 2015-03-03      4.76
# 2015-03-04      2.30
# 2015-03-05      3.19
# 2015-03-06      6.16

# %%
sr = data["price_change"]

# %%
sr.sort_values(ascending=False).head()
# Out:
# 2015-06-09    3.03
# 2017-10-26    2.68
# 2015-05-21    2.57
# 2017-10-31    2.38
# 2017-06-22    2.36
# Name: price_change, dtype: float64

# %%
sr.sort_index().head()
# Out:
# 2015-03-02    0.32
# 2015-03-03    0.18
# 2015-03-04    0.20
# 2015-03-05    0.26
# 2015-03-06    1.12
# Name: price_change, dtype: float64

# %% [markdown]
# ### 算术运算

# %%
data["open"].add(3).head()
# Out:
# 2018-02-27    103
# 2018-02-26    225
# 2018-02-23    103
# 2018-02-22    103
# 2018-02-14    103
# Name: open, dtype: int64

# %%
data.sub(100).head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27     0 -74.12 -75.84 -76.47  95478.03        -99.37    -97.32
# 2018-02-26   122 -76.22 -76.47 -77.20  60885.11        -99.31    -96.98
# 2018-02-23     0 -76.63 -77.18 -77.29  52814.01        -99.46    -97.58
# 2018-02-22     0 -77.24 -77.72 -77.98  36005.01        -99.64    -98.36
# 2018-02-14     0 -78.01 -78.08 -78.52  23231.04        -99.56    -97.95
#
#             turnover
# 2018-02-27    -97.61
# 2018-02-26    -98.47
# 2018-02-23    -98.68
# 2018-02-22    -99.10
# 2018-02-14    -99.42

# %%
data["close"].sub(data["open"]).head()
# Out:
# 2018-02-27    -75.84
# 2018-02-26   -198.47
# 2018-02-23    -77.18
# 2018-02-22    -77.72
# 2018-02-14    -78.08
# dtype: float64

# %% [markdown]
# ### 逻辑运算符号<、 >、|、 &

# %%
data["p_change"] > 2
# Out:
# 2018-02-27     True
# 2018-02-26     True
# 2018-02-23     True
# 2018-02-22    False
# 2018-02-14     True
#               ...
# 2015-03-06     True
# 2015-03-05     True
# 2015-03-04    False
# 2015-03-03    False
# 2015-03-02     True
# Name: p_change, Length: 643, dtype: bool

# %%
# 例如筛选p_change > 2的日期数据
data[data["p_change"] > 2].head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
# 完成一个多个逻辑判断， 筛选p_change > 2并且low > 15
data[(data["p_change"] > 2) & (data["low"] > 15)].head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
data.query("p_change > 2 & low > 15").head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
# 判断'turnover'是否为4.19, 2.39
data[data["turnover"].isin([4.19, 2.39])]
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53   95578.03          0.63      2.68
# 2017-07-25   100  24.20  23.70  22.64  167489.48          0.67      2.91
# 2016-09-28   100  20.98  20.86  19.71   95580.75          0.98      4.93
# 2015-04-07   100  17.98  17.54  16.50  122471.85          0.88      5.28
#
#             turnover
# 2018-02-27      2.39
# 2017-07-25      4.19
# 2016-09-28      2.39
# 2015-04-07      4.19

# %% [markdown]
# ### 统计运算

# %%
data.describe()
# Out:
#              open        high       close         low         volume  \
# count  643.000000  643.000000  643.000000  643.000000     643.000000
# mean   100.189736   21.900513   21.336267   20.771835   99905.519114
# std      4.811210    4.077578    3.942806    3.791968   73879.119354
# min    100.000000   12.670000   12.360000   12.200000    1158.120000
# 25%    100.000000   19.500000   19.045000   18.525000   48533.210000
# 50%    100.000000   21.970000   21.450000   20.980000   83175.930000
# 75%    100.000000   24.065000   23.415000   22.850000  127580.055000
# max    222.000000   36.350000   35.210000   34.010000  501915.410000
#
#        price_change    p_change    turnover
# count    643.000000  643.000000  643.000000
# mean       0.018802    0.190280    2.936190
# std        0.898476    4.079698    2.079375
# min       -3.520000  -10.030000    0.040000
# 25%       -0.390000   -1.850000    1.360000
# 50%        0.050000    0.260000    2.500000
# ...

# %%
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
data.max(axis=0)
# Out:
# open               222.00
# high                36.35
# close               35.21
# low                 34.01
# volume          501915.41
# price_change         3.03
# p_change            10.03
# turnover            12.56
# dtype: float64

# %%
data.idxmax(axis=0)
# Out:
# open            2018-02-26
# high            2015-06-10
# close           2015-06-12
# low             2015-06-12
# volume          2017-10-26
# price_change    2015-06-09
# p_change        2015-08-28
# turnover        2017-10-26
# dtype: object

# %% [markdown]
# ### 累计统计函数

# %%
data["p_change"]
# Out:
# 2018-02-27    2.68
# 2018-02-26    3.02
# 2018-02-23    2.42
# 2018-02-22    1.64
# 2018-02-14    2.05
#               ...
# 2015-03-06    8.51
# 2015-03-05    2.02
# 2015-03-04    1.57
# 2015-03-03    1.44
# 2015-03-02    2.62
# Name: p_change, Length: 643, dtype: float64

# %%
data["p_change"].cumsum()
# Out:
# 2018-02-27      2.68
# 2018-02-26      5.70
# 2018-02-23      8.12
# 2018-02-22      9.76
# 2018-02-14     11.81
#                ...
# 2015-03-06    114.70
# 2015-03-05    116.72
# 2015-03-04    118.29
# 2015-03-03    119.73
# 2015-03-02    122.35
# Name: p_change, Length: 643, dtype: float64

# %%
data["p_change"].sort_index().cumsum().plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 自定义运算

# %%
data.apply(lambda x: x.max() - x.min())
# Out:
# open               122.00
# high                23.68
# close               22.85
# low                 21.81
# volume          500757.29
# price_change         6.55
# p_change            20.06
# turnover            12.52
# dtype: float64

# %%
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   222  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
data["volume"].max() - data["volume"].min()
# Out:
# 500757.29

# %%
data.plot(x="volume", y="turnover", kind="scatter")
# Out:
# <Axes: xlabel='volume', ylabel='turnover'>

# %%
data.plot(x="high", y="low", kind="scatter")
# Out:
# <Axes: xlabel='high', ylabel='low'>

# %% [markdown]
# ### 读取csv文件-read_csv()

# %%
pd.read_csv("./stock_day.csv", usecols=["high", "low", "open", "close"]).head()
# Out:
#              open   high  close    low
# 2018-02-27  23.53  25.88  24.16  23.53
# 2018-02-26  22.80  23.78  23.53  22.80
# 2018-02-23  22.88  23.37  22.82  22.71
# 2018-02-22  22.25  22.76  22.28  22.02
# 2018-02-14  21.49  21.99  21.92  21.48

# %%
data = pd.read_csv("stock_day2.csv", names=["open", "high", "close", "low", "volume", "price_change", "p_change", "ma5", "ma10", "ma20", "v_ma5", "v_ma10", "v_ma20", "turnover"])

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# ...

# %%
# 保存'open'列的数据
data[:10].to_csv("test.csv", columns=["open"])

# %%
pd.read_csv("test.csv")
# Out:
#    Unnamed: 0   open
# 0  2018-02-27  23.53
# 1  2018-02-26  22.80
# 2  2018-02-23  22.88
# 3  2018-02-22  22.25
# 4  2018-02-14  21.49
# 5  2018-02-13  21.40
# 6  2018-02-12  20.70
# 7  2018-02-09  21.20
# 8  2018-02-08  21.79
# 9  2018-02-07  22.69

# %%
data[:10].to_csv("test.csv", columns=["open"], index=False, mode="w", header=True)

# %%
pd.read_csv("test.csv")
# Out:
#     open
# 0  23.53
# 1  22.80
# 2  22.88
# 3  22.25
# 4  21.49
# 5  21.40
# 6  20.70
# 7  21.20
# 8  21.79
# 9  22.69

# %% [markdown]
# ### HDF5

# %%
day_close = pd.read_hdf("day_close.h5")

# %%
day_close.to_hdf("test.h5", key="close")

# %%
pd.read_hdf("test.h5", key="close").head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      16.30      17.71       4.58       2.88      14.60       2.62
# 1      17.02      19.20       4.65       3.02      15.97       2.65
# 2      17.02      17.28       4.56       3.06      14.37       2.63
# 3      16.18      16.97       4.49       2.95      13.10       2.73
# 4      16.95      17.19       4.55       2.99      13.18       2.77
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# 0       4.96       4.66       5.37       6.02  ...        NaN        NaN
# 1       4.95       4.70       5.37       6.27  ...        NaN        NaN
# 2       4.82       4.47       5.37       5.96  ...        NaN        NaN
# 3       4.89       4.33       5.37       5.77  ...        NaN        NaN
# 4       4.97       4.42       5.37       5.92  ...        NaN        NaN
#
#    002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  603329.SH  \
# ...

# %%
day_open = pd.read_hdf("day_open.h5")

# %%
day_open.to_hdf("test.h5", key="open")

# %%
pd.read_hdf("test.h5", key="close").head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      16.30      17.71       4.58       2.88      14.60       2.62
# 1      17.02      19.20       4.65       3.02      15.97       2.65
# 2      17.02      17.28       4.56       3.06      14.37       2.63
# 3      16.18      16.97       4.49       2.95      13.10       2.73
# 4      16.95      17.19       4.55       2.99      13.18       2.77
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# 0       4.96       4.66       5.37       6.02  ...        NaN        NaN
# 1       4.95       4.70       5.37       6.27  ...        NaN        NaN
# 2       4.82       4.47       5.37       5.96  ...        NaN        NaN
# 3       4.89       4.33       5.37       5.77  ...        NaN        NaN
# 4       4.97       4.42       5.37       5.92  ...        NaN        NaN
#
#    002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  603329.SH  \
# ...

# %%
pd.read_hdf("test.h5", key="open").head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      15.50      16.15       4.26       2.73      13.99       2.52
# 1      16.50      17.94       4.53       2.91      14.78       2.61
# 2      17.00      18.80       4.63       3.04      16.08       2.65
# 3      16.95      16.59       4.52       3.02      13.20       2.63
# 4      16.20      16.96       4.50       2.95      13.17       2.80
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# 0       4.76       4.45       5.37       5.79  ...        NaN        NaN
# 1       4.99       4.69       5.37       6.03  ...        NaN        NaN
# 2       4.96       4.73       5.37       6.26  ...        NaN        NaN
# 3       4.81       4.35       5.37       5.74  ...        NaN        NaN
# 4       4.88       4.34       5.37       5.80  ...        NaN        NaN
#
#    002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  603329.SH  \
# ...

# %% [markdown]
# ### JSON

# %%
sa = pd.read_json("Sarcasm_Headlines_Dataset.json", orient="records", lines=True)

# %%
sa.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %%
sa.to_json("test.json", orient="records", lines=True)
